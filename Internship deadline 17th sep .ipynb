# %%
# !pip install bs4
# !pip install requests

# %%
# importing the required liabraries 
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get('https://en.wikipedia.org/wiki/Main_Page')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-disabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
first_title = soup.find('div',class_="mp-contains-float")
first_title
# Out:
# <div class="mp-contains-float" id="mp-tfa"><div id="mp-tfa-img" style="float: left; margin: 0.5em 0.9em 0.4em 0em;">
# <div class="thumbinner mp-thumb" style="background: transparent; border: none; padding: 0; max-width: 125px;">
# <span typeof="mw:File"><a class="mw-file-description" href="/wiki/File:Lisa_M._Nowak.jpg" title="Lisa Nowak"><img alt="Lisa Nowak" class="mw-file-element" data-file-height="4000" data-file-width="3200" decoding="async" height="156" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/51/Lisa_M._Nowak.jpg/125px-Lisa_M._Nowak.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/51/Lisa_M._Nowak.jpg/188px-Lisa_M._Nowak.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/51/Lisa_M._Nowak.jpg/250px-Lisa_M._Nowak.jpg 2x" width="125"/></a></span></div>
# </div>
# ...

# %%
first_title.text
# Out:
# '\n\n\n\nLisa Nowak (born 1963) is a former NASA astronaut and United States Navy officer. Nowak graduated from the Naval Academy in 1985. A naval aviator, in 1993, after initial flight assignments and earning two graduate degrees, she was selected to attend the Naval Test Pilot School. She was selected for NASA Astronaut Group\xa016 in 1996, qualifying as a mission specialist in robotics. She flew in space in July 2006 aboard Space Shuttle Discovery during the STS-121 mission, where she was responsible for operating the robotic arms of the shuttle and the International Space Station. In February\xa02007, Nowak was involved in a highly publicized incident in Orlando, Florida, accused of assaulting a woman romantically involved with astronaut William Oefelein, who had been in a relationship with Nowak. In 2009, she pled guilty, resulting in her demotion from captain to commander, and termination by NASA and the Navy. (Full\xa0article...)\n\n\nRecently featured: \n1867 United States Se
# ...

# %%
page = requests.get('https://presidentofindia.nic.in/former-presidents.htm')

# %%
page
# Out:
# <Response [404]>

# %%
page = requests.get('https://presidentofindia.nic.in/former-presidents')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="Drupal 9 (https://www.drupal.org)" name="Generator"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/sites/default/files/tiranga_1.png" rel="icon" type="image/png"/>
# <title>Former Presidents of India | President of India</title>
# <link href="/libraries/superfish/css/superfish.css?s0x9xr" media="all" rel="stylesheet"/>
# <link href="/core/modules/system/css/components/ajax-progress.module.css?s0x9xr" media="all" rel="stylesheet"/>
# <link href="/core/modules/system/css/components/align.module.css?s0x9xr" media="all" rel="stylesheet"/>
# <link href="/core/modules/system/css/components/autocomplete-loading.module.css?s0x9xr" media="all" rel="stylesheet"/>
# ...

# %%
titles = [] #empty list for store the

for i  in soup.find_all('div',class_="president-listing"):
    titles.append (i.text)

# %%
titles
# Out:
# ['\n\n \n\n\nShri Ram Nath Kovind\n14th President of India\n\n\n',
#  '\n\n \n\n\nShri Pranab Mukherjee\n13th President of India\n\n\n',
#  '\n\n \n\n\nSmt Pratibha Devisingh Patil\n12th President of India\n\n\n',
#  '\n\n \n\n\nDR. A.P.J. Abdul Kalam\n11th President of India\n\n\n',
#  '\n\n \n\n\nShri K. R. Narayanan\n10th President of India\n\n\n',
#  '\n\n \n\n\nDr Shankar Dayal Sharma\n9th  President of India\n\n\n',
#  '\n\n \n\n\nShri R Venkataraman\n8th President of India\n\n\n',
#  '\n\n \n\n\nGiani Zail Singh\n7th President of India\n\n\n',
#  '\n\n \n\n\nShri Neelam Sanjiva Reddy\n6th President of India\n\n\n',
#  '\n\n \n\n\nDr. Fakhruddin Ali Ahmed\n5th President of India\n\n\n',
#  '\n\n \n\n\nShri Varahagiri Venkata Giri\n4th President of India\n\n\n',
#  '\n\n \n\n\nDr. Zakir Husain\n3rd President of India\n\n\n',
#  '\n\n \n\n\nDr. Sarvepalli Radhakrishnan\n2nd President of India\n\n\n',
#  '\n\n \n\n\nDr. Rajendra Prasad\n1st President of India\n\n\n']

# %%
page = requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/test')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's Test Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for test match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for test match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's Test Player Rankings | ICC" property="og:title"/>
# ...

# %%
first_title = soup.find('span',class_="table-head__cell u-center-text")
first_title

# %%
matches_title = soup.find('span',class_="u-hide-phablet")
matches_title

# %%
points_title = soup.find('span',class_="u-hide-mobile")
points_title

# %%
points_title = soup.find('span',class_="u-hide-mobile">Points,'span')
points_title
# Out:
#   Cell In[55], line 1
#     points_title = soup.find('span',class_="u-hide-mobile">Points,'span')
#                                                                         ^
# SyntaxError: positional argument follows keyword argument

# %%
rating_title = soup.find('span',class_="u-hide-mobile")
rating_title

# %%
page = requests.get('https://www.cnbc.com/world/?region=world')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
first_title = soup.find('span', class_="Latest News")
first_title

# %%
first_title
